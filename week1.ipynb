# %% [markdown]
# <a href="https://colab.research.google.com/github/Navyasri-18/Python-pandas-practice/blob/main/week1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('/content/research-and-development-survey-2023.csv', encoding='latin1')

# %%
df
# Out:
#                                               Variable       Breakdown  \
# 0                             _01_Total_RD_Expenditure  ANZSIC_1_Digit
# 1                             _01_Total_RD_Expenditure  ANZSIC_1_Digit
# 2                             _01_Total_RD_Expenditure  ANZSIC_1_Digit
# 3                             _01_Total_RD_Expenditure  ANZSIC_1_Digit
# 4                             _01_Total_RD_Expenditure  ANZSIC_1_Digit
# ...                                                ...             ...
# 42522  _95_Total_RD_Expenditure_as_a_proportion_of_GDP         Country
# 42523  _95_Total_RD_Expenditure_as_a_proportion_of_GDP         Country
# 42524  _95_Total_RD_Expenditure_as_a_proportion_of_GDP         Country
# 42525  _95_Total_RD_Expenditure_as_a_proportion_of_GDP         Country
# 42526  _95_Total_RD_Expenditure_as_a_proportion_of_GDP         Country
#
#                         Breakdown_category  Year RD_Value Status  \
# ...

# %%
df.head(6)
# Out:
#                    Variable       Breakdown  \
# 0  _01_Total_RD_Expenditure  ANZSIC_1_Digit
# 1  _01_Total_RD_Expenditure  ANZSIC_1_Digit
# 2  _01_Total_RD_Expenditure  ANZSIC_1_Digit
# 3  _01_Total_RD_Expenditure  ANZSIC_1_Digit
# 4  _01_Total_RD_Expenditure  ANZSIC_1_Digit
# 5  _01_Total_RD_Expenditure  ANZSIC_1_Digit
#
#                     Breakdown_category  Year RD_Value Status  \
# 0  A_Agriculture, Forestry and Fishing  2016       91    NaN
# 1  A_Agriculture, Forestry and Fishing  2018       89    NaN
# 2  A_Agriculture, Forestry and Fishing  2019      ...    NaN
# 3  A_Agriculture, Forestry and Fishing  2020       99    NaN
# 4  A_Agriculture, Forestry and Fishing  2021      ...    NaN
# 5  A_Agriculture, Forestry and Fishing  2022       94      P
#
#                     Unit Footnotes Relative_Sampling_Error
# 0  NZ Dollars (millions)        12                    23.8
# 1  NZ Dollars (millions)        12                    51.7
# ...

# %%
df.tail(8)
# Out:
#                                               Variable Breakdown  \
# 42519  _95_Total_RD_Expenditure_as_a_proportion_of_GDP   Country
# 42520  _95_Total_RD_Expenditure_as_a_proportion_of_GDP   Country
# 42521  _95_Total_RD_Expenditure_as_a_proportion_of_GDP   Country
# 42522  _95_Total_RD_Expenditure_as_a_proportion_of_GDP   Country
# 42523  _95_Total_RD_Expenditure_as_a_proportion_of_GDP   Country
# 42524  _95_Total_RD_Expenditure_as_a_proportion_of_GDP   Country
# 42525  _95_Total_RD_Expenditure_as_a_proportion_of_GDP   Country
# 42526  _95_Total_RD_Expenditure_as_a_proportion_of_GDP   Country
#
#       Breakdown_category  Year RD_Value Status               Unit  Footnotes  \
# 42519     United Kingdom  2020     2.93    NaN  Percentage of GDP  33 and 34
# 42520     United Kingdom  2021     2.91    NaN  Percentage of GDP  33 and 34
# 42521      United States  2016     2.85    NaN  Percentage of GDP  33 and 34
# ...

# %%
df.describe()
# Out:
#                Year
# count  42527.000000
# mean    2019.823124
# std        2.230453
# min     2016.000000
# 25%     2018.000000
# 50%     2020.000000
# 75%     2022.000000
# max     2023.000000

# %%
df.shape
# Out:
# (42527, 9)
